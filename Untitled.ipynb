# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
train_loss = reader('logs/model=vgg16_optimizer:adam_lr=0.0001_reg=0.0001_batch_size=10_epochs=5_dropout=0.0/train_loss_hist')
train_acc = reader('logs/model=vgg16_optimizer:adam_lr=0.0001_reg=0.0001_batch_size=10_epochs=5_dropout=0.0/train_acc_hist')
dev_loss = reader('logs/model=vgg16_optimizer:adam_lr=0.0001_reg=0.0001_batch_size=10_epochs=5_dropout=0.0/dev_loss_hist')
dev_acc = reader('logs/model=vgg16_optimizer:adam_lr=0.0001_reg=0.0001_batch_size=10_epochs=5_dropout=0.0/dev_acc_hist')

# %%
sns.set_context("paper", font_scale=1.5)

# %%
plt.plot(train_loss, label='train')
plt.plot(dev_loss, label='dev')
plt.title('Loss history')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('loss.pdf')

# %%
plt.plot(train_acc, label='train')
plt.plot(dev_acc, label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.savefig('acc.pdf')
